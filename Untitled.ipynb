# %%
###Search Audio API EXAMPLE###

# search_url_audio = "https://api.spotify.com/v1/audio-features/"
# audio_url = search_url_audio + "59PYgzOiOjGDzjDT5N5oOX"

# audio_json = requests.get(audio_url, headers = token_headers).json()

import os
import time
import requests
import numpy as np
import pandas as pd
from requests.auth import HTTPBasicAuth
from client import client_id, client_secret
import sqlalchemy

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
# Create engine using the `demographics.sqlite` database file
#engine = create_engine("sqlite:///../Resources/demographics.sqlite")
rds_connection_string = "root:root@127.0.0.1/customer_db"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# connection_string = "root:<insert password>@localhost/customer_db"
# engine = create_engine(f'mysql://{connection_string}')

# %%
path = "practice_country_CSV"

try:  
    os.mkdir(path)

except OSError:  
    print ("Creation of the directory %s failed" % path)
    
else:  
    print ("Successfully created the directory %s " % path)
# Out:
# Creation of the directory practice_country_CSV failed

# %%
## Top 50 Playlist by Country Excel
top50_playlist_df = pd.read_excel("Resources/Top50_Playlist_by_Country.xlsm")

# %%
## This request grants us a temporary token to use to access the json data from spotify.
token_url = "https://accounts.spotify.com/api/token"
headers = {'content-type': 'application/x-www-form-urlencoded'}

token_params = {"grant_type" : "client_credentials"}

token_json = requests.post(token_url, params = token_params, headers = headers, auth = (client_id, client_secret)).json()
token = token_json['access_token']
#token_json

# %%
# Required header to access spotify api
token_headers = {'authorization': f"Bearer {token}"}

# %%
# Counter is used to grab country name from top50_playlist_df
counter = 0

# %%
# Search api endpoint for playlist and audio features
search_url_playlist = "https://api.spotify.com/v1/playlists/"
# search_url_audio = "https://api.spotify.com/v1/audio-features/"

# %%
print("--------------------------\nBegin Importing Spotify JSON\n--------------------------")
#counter for tracking queries
query = 1
#Loops through each playlist ID from top50_playlist_df
for playlist_id in top50_playlist_df["Spotify Playlist ID"]:
# playlist_id = top50_playlist_df["Spotify Playlist ID"][1]
    
    playlist_url = search_url_playlist + playlist_id
    
    # Store entire playlist json data into variable
    playlist_json = requests.get(playlist_url, headers = token_headers).json()
    
    # List to store json data
    artist_name = []
    artist_id = []
    track_name = []
    track_id = []
    #release_date = []
    #popularity = []
    #danceability = []
    #energy = []
    
    query+=1
    # Number of tracks within each playlist (should be 50 songs)
    number_of_tracks = len(playlist_json["tracks"]["items"])
    
    print(f"--------------------------\nFinish {query} Spotify Query\n--------------------------")
# playlist_url = search_url_playlist + playlist_id
    
# # Store entire playlist json data into variable
# playlist_json = requests.get(playlist_url, headers = token_headers).json()
    
# # List to store json data
# artist_name = []
# artist_id = []
# track_name = []
# track_id = []
#     #release_date = []
#     #popularity = []
#     #danceability = []
#     #energy = []
    
# query+=1
#     # Number of tracks within each playlist (should be 50 songs)
# number_of_tracks = len(playlist_json["tracks"]["items"])
    
# print(f"--------------------------\nFinish {query} Spotify Query\n--------------------------")

playlist_json
# Out:
# --------------------------
# Begin Importing Spotify JSON
# --------------------------
# --------------------------
# Finish 2 Spotify Query
# --------------------------
# --------------------------
# Finish 3 Spotify Query
# --------------------------
# --------------------------
# Finish 4 Spotify Query
# --------------------------
# --------------------------
# Finish 5 Spotify Query
# --------------------------
# --------------------------
# Finish 6 Spotify Query
# --------------------------
# --------------------------
# Finish 7 Spotify Query
# --------------------------
# --------------------------
# Finish 8 Spotify Query
# --------------------------
# --------------------------
# Finish 9 Spotify Query
# --------------------------
# --------------------------
# Finish 10 Spotify Query
# --------------------------
# --------------------------
# Finish 11 Spotify Query
# --------------------------
# --------------------------
# Finish 12 Spotify Query
# --------------------------
# --------------------------
# Finish 13 Spotify Query
# --------------------------
# --------------------------
# Finish 14 Spotify Query
# --------------------------
# {'collaborative': False,
#  'description': 'Your daily update of the most played tracks in Argentina right now.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbMMy2roB9myp'},
#  'followers': {'href': None, 'total': 572737},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMMy2roB9myp',
#  'id': '37i9dQZEVXbMMy2roB9myp',
#  'images': [{'height': None,
#    'url': 'https://charts-images.scdn.co/REGIONAL_AR_DEFAULT.jpg',
#    'width': None}],
#  'name': 'Argentina Top 50',
#  'owner': {'display_name': 'spotifycharts',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotifycharts'},
#   'href': 'https://api.spotify.com/v1/users/spotifycharts',
#   'id': 'spotifycharts',
#   'type': 'user',
#   'uri': 'spotify:user:spotifycharts'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'NjA3OTU0MzM4LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMMy2roB9myp/tracks?offset=0&limit=100',
#   'items': [{'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#         'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#         'id': '4VMYDCV2IEDYJArk749S6m',
#         'name': 'Daddy Yankee',
#         'type': 'artist',
#         'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1otwHKoQ5KPaiekpYk4tWh'},
#       'href': 'https://api.spotify.com/v1/albums/1otwHKoQ5KPaiekpYk4tWh',
#       'id': '1otwHKoQ5KPaiekpYk4tWh',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/24138579eae01fad78c54cbaa22901ded90c8066',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/9b260b5356807cef9d31235bb3c132d1e7ec8360',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/795b8633e3716e2acbd0add9a0c6900f7034bbf5',
#         'width': 64}],
#       'name': 'Con Calma',
#       'release_date': '2019-01-24',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:1otwHKoQ5KPaiekpYk4tWh'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#        'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#        'id': '4VMYDCV2IEDYJArk749S6m',
#        'name': 'Daddy Yankee',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3uZFBSsMiooimnprFL9jD1'},
#        'href': 'https://api.spotify.com/v1/artists/3uZFBSsMiooimnprFL9jD1',
#        'id': '3uZFBSsMiooimnprFL9jD1',
#        'name': 'Snow',
#        'type': 'artist',
#        'uri': 'spotify:artist:3uZFBSsMiooimnprFL9jD1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 193226,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'US2BU1900125'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5w9c2J52mkdntKOmRLeM2m'},
#      'href': 'https://api.spotify.com/v1/tracks/5w9c2J52mkdntKOmRLeM2m',
#      'id': '5w9c2J52mkdntKOmRLeM2m',
#      'is_local': False,
#      'name': 'Con Calma',
#      'popularity': 100,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5w9c2J52mkdntKOmRLeM2m'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KPX4Ucy9dk82uj4GpKesn'},
#         'href': 'https://api.spotify.com/v1/artists/0KPX4Ucy9dk82uj4GpKesn',
#         'id': '0KPX4Ucy9dk82uj4GpKesn',
#         'name': 'Dalex',
#         'type': 'artist',
#         'uri': 'spotify:artist:0KPX4Ucy9dk82uj4GpKesn'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/11YLRSsZA3YVuQQtHXKTlz'},
#         'href': 'https://api.spotify.com/v1/artists/11YLRSsZA3YVuQQtHXKTlz',
#         'id': '11YLRSsZA3YVuQQtHXKTlz',
#         'name': 'Rafa Pabön',
#         'type': 'artist',
#         'uri': 'spotify:artist:11YLRSsZA3YVuQQtHXKTlz'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/4m6ubhNsdwF4psNf3R8kwR'},
#         'href': 'https://api.spotify.com/v1/artists/4m6ubhNsdwF4psNf3R8kwR',
#         'id': '4m6ubhNsdwF4psNf3R8kwR',
#         'name': 'Khea',
#         'type': 'artist',
#         'uri': 'spotify:artist:4m6ubhNsdwF4psNf3R8kwR'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4OyP4eAtpTHXjpVBjJvPNG'},
#       'href': 'https://api.spotify.com/v1/albums/4OyP4eAtpTHXjpVBjJvPNG',
#       'id': '4OyP4eAtpTHXjpVBjJvPNG',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/be7b75b6dde0ea407a96c9c358fd90ba6f738fa6',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/24b56a374206acec5676d9152baf59013bb6fb2c',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/0ec20fcc08b03a70cfb9d005e46cb1d3ce68c457',
#         'width': 64}],
#       'name': 'Pa Mí (Remix)',
#       'release_date': '2019-02-07',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:4OyP4eAtpTHXjpVBjJvPNG'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KPX4Ucy9dk82uj4GpKesn'},
#        'href': 'https://api.spotify.com/v1/artists/0KPX4Ucy9dk82uj4GpKesn',
#        'id': '0KPX4Ucy9dk82uj4GpKesn',
#        'name': 'Dalex',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KPX4Ucy9dk82uj4GpKesn'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/11YLRSsZA3YVuQQtHXKTlz'},
#        'href': 'https://api.spotify.com/v1/artists/11YLRSsZA3YVuQQtHXKTlz',
#        'id': '11YLRSsZA3YVuQQtHXKTlz',
#        'name': 'Rafa Pabön',
#        'type': 'artist',
#        'uri': 'spotify:artist:11YLRSsZA3YVuQQtHXKTlz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4m6ubhNsdwF4psNf3R8kwR'},
#        'href': 'https://api.spotify.com/v1/artists/4m6ubhNsdwF4psNf3R8kwR',
#        'id': '4m6ubhNsdwF4psNf3R8kwR',
#        'name': 'Khea',
#        'type': 'artist',
#        'uri': 'spotify:artist:4m6ubhNsdwF4psNf3R8kwR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/77ziqFxp5gaInVrF2lj4ht'},
#        'href': 'https://api.spotify.com/v1/artists/77ziqFxp5gaInVrF2lj4ht',
#        'id': '77ziqFxp5gaInVrF2lj4ht',
#        'name': 'Sech',
#        'type': 'artist',
#        'uri': 'spotify:artist:77ziqFxp5gaInVrF2lj4ht'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6w3SkAHYPsQ1bxV7VDlG5y'},
#        'href': 'https://api.spotify.com/v1/artists/6w3SkAHYPsQ1bxV7VDlG5y',
#        'id': '6w3SkAHYPsQ1bxV7VDlG5y',
#        'name': 'Cazzu',
#        'type': 'artist',
#        'uri': 'spotify:artist:6w3SkAHYPsQ1bxV7VDlG5y'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#        'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#        'id': '2LRoIwlKmHjgvigdNGBHNo',
#        'name': 'Feid',
#        'type': 'artist',
#        'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1pQWsZQehhS4wavwh7Fnxd'},
#        'href': 'https://api.spotify.com/v1/artists/1pQWsZQehhS4wavwh7Fnxd',
#        'id': '1pQWsZQehhS4wavwh7Fnxd',
#        'name': 'Lenny Tavárez',
#        'type': 'artist',
#        'uri': 'spotify:artist:1pQWsZQehhS4wavwh7Fnxd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 360960,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'QM9WM1900002'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/224EVTFiLsdQignUFLvDeH'},
#      'href': 'https://api.spotify.com/v1/tracks/224EVTFiLsdQignUFLvDeH',
#      'id': '224EVTFiLsdQignUFLvDeH',
#      'is_local': False,
#      'name': 'Pa Mí - Remix',
#      'popularity': 93,
#      'preview_url': 'https://p.scdn.co/mp3-preview/99bf02294818b0f72efaa135e1d42cc20584ef6e?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:224EVTFiLsdQignUFLvDeH'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01m2XZ7m7rAz6KY3scTdaV'},
#         'href': 'https://api.spotify.com/v1/artists/01m2XZ7m7rAz6KY3scTdaV',
#         'id': '01m2XZ7m7rAz6KY3scTdaV',
#         'name': 'Neo Pistea',
#         'type': 'artist',
#         'uri': 'spotify:artist:01m2XZ7m7rAz6KY3scTdaV'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/36ehOw44KSj8riww8Eamd8'},
#       'href': 'https://api.spotify.com/v1/albums/36ehOw44KSj8riww8Eamd8',
#       'id': '36ehOw44KSj8riww8Eamd8',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/1fd6f5cbe71a48f8b18676f36b7e8904f58babf4',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/1c1eedbc9ffe91644efca13265eb9e6377e22b13',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/25bf1d8fe6c96828d293b3d084cd419dd9dd1abc',
#         'width': 64}],
#       'name': 'Tumbando el Club (feat. C.R.O., Obiewanshot, Ysy A, Cazzu, Khea, Lucho SSJ, Coqeéin Montana, Marcianos Crew & Duki) [Remix]',
#       'release_date': '2019-03-27',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:36ehOw44KSj8riww8Eamd8'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01m2XZ7m7rAz6KY3scTdaV'},
#        'href': 'https://api.spotify.com/v1/artists/01m2XZ7m7rAz6KY3scTdaV',
#        'id': '01m2XZ7m7rAz6KY3scTdaV',
#        'name': 'Neo Pistea',
#        'type': 'artist',
#        'uri': 'spotify:artist:01m2XZ7m7rAz6KY3scTdaV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3utZ2yeQk0Z3BCOBWP7Vlu'},
#        'href': 'https://api.spotify.com/v1/artists/3utZ2yeQk0Z3BCOBWP7Vlu',
#        'id': '3utZ2yeQk0Z3BCOBWP7Vlu',
#        'name': 'Cro',
#        'type': 'artist',
#        'uri': 'spotify:artist:3utZ2yeQk0Z3BCOBWP7Vlu'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/48vP5SxlTO6yOI7SLKIOQV'},
#        'href': 'https://api.spotify.com/v1/artists/48vP5SxlTO6yOI7SLKIOQV',
#        'id': '48vP5SxlTO6yOI7SLKIOQV',
#        'name': 'Obie Wanshot',
#        'type': 'artist',
#        'uri': 'spotify:artist:48vP5SxlTO6yOI7SLKIOQV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2qWK8K2Jfh67UqtwY8tCW6'},
#        'href': 'https://api.spotify.com/v1/artists/2qWK8K2Jfh67UqtwY8tCW6',
#        'id': '2qWK8K2Jfh67UqtwY8tCW6',
#        'name': 'Ysy A',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qWK8K2Jfh67UqtwY8tCW6'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6w3SkAHYPsQ1bxV7VDlG5y'},
#        'href': 'https://api.spotify.com/v1/artists/6w3SkAHYPsQ1bxV7VDlG5y',
#        'id': '6w3SkAHYPsQ1bxV7VDlG5y',
#        'name': 'Cazzu',
#        'type': 'artist',
#        'uri': 'spotify:artist:6w3SkAHYPsQ1bxV7VDlG5y'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4m6ubhNsdwF4psNf3R8kwR'},
#        'href': 'https://api.spotify.com/v1/artists/4m6ubhNsdwF4psNf3R8kwR',
#        'id': '4m6ubhNsdwF4psNf3R8kwR',
#        'name': 'Khea',
#        'type': 'artist',
#        'uri': 'spotify:artist:4m6ubhNsdwF4psNf3R8kwR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1OBizG9nrnHJkrL9NjnWYN'},
#        'href': 'https://api.spotify.com/v1/artists/1OBizG9nrnHJkrL9NjnWYN',
#        'id': '1OBizG9nrnHJkrL9NjnWYN',
#        'name': 'Lucho SSJ',
#        'type': 'artist',
#        'uri': 'spotify:artist:1OBizG9nrnHJkrL9NjnWYN'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4StQh17zinsbJ4r5ekmPj7'},
#        'href': 'https://api.spotify.com/v1/artists/4StQh17zinsbJ4r5ekmPj7',
#        'id': '4StQh17zinsbJ4r5ekmPj7',
#        'name': 'Coqeéin Montana',
#        'type': 'artist',
#        'uri': 'spotify:artist:4StQh17zinsbJ4r5ekmPj7'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Hkx0YcHHxDRRbH9WsSW0I'},
#        'href': 'https://api.spotify.com/v1/artists/0Hkx0YcHHxDRRbH9WsSW0I',
#        'id': '0Hkx0YcHHxDRRbH9WsSW0I',
#        'name': 'Marcianos Crew',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Hkx0YcHHxDRRbH9WsSW0I'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bAftSH8umNcGZ0uyV7LMg'},
#        'href': 'https://api.spotify.com/v1/artists/1bAftSH8umNcGZ0uyV7LMg',
#        'id': '1bAftSH8umNcGZ0uyV7LMg',
#        'name': 'Duki',
#        'type': 'artist',
#        'uri': 'spotify:artist:1bAftSH8umNcGZ0uyV7LMg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 456939,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'ARF101900138'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0OWcpVA83HI8Pb5DybDuoX'},
#      'href': 'https://api.spotify.com/v1/tracks/0OWcpVA83HI8Pb5DybDuoX',
#      'id': '0OWcpVA83HI8Pb5DybDuoX',
#      'is_local': False,
#      'name': 'Tumbando el Club (feat. C.R.O., Obiewanshot, Ysy A, Cazzu, Khea, Lucho SSJ, Coqeéin Montana, Marcianos Crew & Duki) - Remix',
#      'popularity': 76,
#      'preview_url': 'https://p.scdn.co/mp3-preview/fb08c0ad23ace6ca5b4fa00fb6789f5f6f7ddd82?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0OWcpVA83HI8Pb5DybDuoX'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#         'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#         'id': '2R21vXR83lH98kGeO99Y66',
#         'name': 'Anuel Aa',
#         'type': 'artist',
#         'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#         'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#         'id': '790FomKkXshlbRYZFtlgla',
#         'name': 'Karol G',
#         'type': 'artist',
#         'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6owzcG80ifZRDApCpzJYK1'},
#       'href': 'https://api.spotify.com/v1/albums/6owzcG80ifZRDApCpzJYK1',
#       'id': '6owzcG80ifZRDApCpzJYK1',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/dc7a8a2efb1cb9da512ded2ec1e5dce967ba50fb',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/b2be44a0aac7c392339509d94322157f9e21a540',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/fd419a231105168e45f4e3c2f2a3a47de14c7feb',
#         'width': 64}],
#       'name': 'Secreto',
#       'release_date': '2019-01-15',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:6owzcG80ifZRDApCpzJYK1'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#        'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#        'id': '2R21vXR83lH98kGeO99Y66',
#        'name': 'Anuel Aa',
#        'type': 'artist',
#        'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#        'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#        'id': '790FomKkXshlbRYZFtlgla',
#        'name': 'Karol G',
#        'type': 'artist',
#        'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 258800,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USXDR1900020'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5W83ErFkO3aKAIS1WMi6u0'},
#      'href': 'https://api.spotify.com/v1/tracks/5W83ErFkO3aKAIS1WMi6u0',
#      'id': '5W83ErFkO3aKAIS1WMi6u0',
#      'is_local': False,
#      'name': 'Secreto',
#      'popularity': 96,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5W83ErFkO3aKAIS1WMi6u0'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4QVBYiagIaa6ZGSPMbybpy'},
#         'href': 'https://api.spotify.com/v1/artists/4QVBYiagIaa6ZGSPMbybpy',
#         'id': '4QVBYiagIaa6ZGSPMbybpy',
#         'name': 'Pedro Capó',
#         'type': 'artist',
#         'uri': 'spotify:artist:4QVBYiagIaa6ZGSPMbybpy'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#         'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#         'id': '329e4yvIujISKGKz1BZZbO',
#         'name': 'Farruko',
#         'type': 'artist',
#         'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1tFnP9PwIMeMIuj92mfswZ'},
#       'href': 'https://api.spotify.com/v1/albums/1tFnP9PwIMeMIuj92mfswZ',
#       'id': '1tFnP9PwIMeMIuj92mfswZ',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/11d0f83f26cc96933fbbecb778e5274e156a1f58',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/d653d3f939fb2940b627c9f43fb9715a15e12dcd',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/f5135b08a7b5b8a9a549561de72574ba5c908543',
#         'width': 64}],
#       'name': 'Calma (Remix)',
#       'release_date': '2018-10-05',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:1tFnP9PwIMeMIuj92mfswZ'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4QVBYiagIaa6ZGSPMbybpy'},
#        'href': 'https://api.spotify.com/v1/artists/4QVBYiagIaa6ZGSPMbybpy',
#        'id': '4QVBYiagIaa6ZGSPMbybpy',
#        'name': 'Pedro Capó',
#        'type': 'artist',
#        'uri': 'spotify:artist:4QVBYiagIaa6ZGSPMbybpy'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#        'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#        'id': '329e4yvIujISKGKz1BZZbO',
#        'name': 'Farruko',
#        'type': 'artist',
#        'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 238200,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSD11800343'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5iwz1NiezX7WWjnCgY5TH4'},
#      'href': 'https://api.spotify.com/v1/tracks/5iwz1NiezX7WWjnCgY5TH4',
#      'id': '5iwz1NiezX7WWjnCgY5TH4',
#      'is_local': False,
#      'name': 'Calma - Remix',
#      'popularity': 96,
#      'preview_url': 'https://p.scdn.co/mp3-preview/acf9b4cf204f350851f699c3a3a360d413056f0b?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5iwz1NiezX7WWjnCgY5TH4'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#         'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#         'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#         'name': 'Paulo Londra',
#         'type': 'artist',
#         'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/039RvHRSbMCfQLsYcg70BQ'},
#       'href': 'https://api.spotify.com/v1/albums/039RvHRSbMCfQLsYcg70BQ',
#       'id': '039RvHRSbMCfQLsYcg70BQ',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/9f396f36116a809da657fd4b1bb4e41818aeaa0f',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/f7c14cd26e9c2d6b7a1e5f8b466d42f52a8cc2f9',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/490aedaca7cb98c7a1bfd5ae7e3fe44678d65c90',
#         'width': 64}],
#       'name': 'Tal Vez',
#       'release_date': '2019-04-03',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:039RvHRSbMCfQLsYcg70BQ'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#        'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#        'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#        'name': 'Paulo Londra',
#        'type': 'artist',
#        'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 264483,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWL11900063'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/46lvmzK8wxAy66tjzXXSh0'},
#      'href': 'https://api.spotify.com/v1/tracks/46lvmzK8wxAy66tjzXXSh0',
#      'id': '46lvmzK8wxAy66tjzXXSh0',
#      'is_local': False,
#      'name': 'Tal Vez',
#      'popularity': 73,
#      'preview_url': 'https://p.scdn.co/mp3-preview/81d539af654a182904987b109ac3d6274d268bed?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:46lvmzK8wxAy66tjzXXSh0'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#         'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#         'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#         'name': 'Paulo Londra',
#         'type': 'artist',
#         'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1XBTyV1if5X9sU4IhpfH5R'},
#       'href': 'https://api.spotify.com/v1/albums/1XBTyV1if5X9sU4IhpfH5R',
#       'id': '1XBTyV1if5X9sU4IhpfH5R',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ae5c1a6aaaada44cc770dd15fb9b50a3baca02e1',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/316243725d15ef3b0c6e57209e18e3b80df9c1e1',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/806215f1bbf03e305790a8674217273c56f2339e',
#         'width': 64}],
#       'name': 'Adan y Eva',
#       'release_date': '2018-11-05',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:1XBTyV1if5X9sU4IhpfH5R'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#        'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#        'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#        'name': 'Paulo Londra',
#        'type': 'artist',
#        'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 258638,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWL11801206'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6FyRXC8tJUh863JCkyWqtk'},
#      'href': 'https://api.spotify.com/v1/tracks/6FyRXC8tJUh863JCkyWqtk',
#      'id': '6FyRXC8tJUh863JCkyWqtk',
#      'is_local': False,
#      'name': 'Adan y Eva',
#      'popularity': 94,
#      'preview_url': 'https://p.scdn.co/mp3-preview/cca5e8fb54c2e4b89bf5107792bf140046811385?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6FyRXC8tJUh863JCkyWqtk'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#         'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#         'id': '1r4hJ1h58CWwUQe3MxPuau',
#         'name': 'Maluma',
#         'type': 'artist',
#         'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4Z6UQR992qmvuH2WLBD1pT'},
#       'href': 'https://api.spotify.com/v1/albums/4Z6UQR992qmvuH2WLBD1pT',
#       'id': '4Z6UQR992qmvuH2WLBD1pT',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/f6efbaa76e067bd48ac6ea64f3cca3429045747b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/d595491e7538d91c89948f248eb09f661dacceaf',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/98035d8803c26779b78610ca1bef353ab27374cd',
#         'width': 64}],
#       'name': 'HP',
#       'release_date': '2019-03-01',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:4Z6UQR992qmvuH2WLBD1pT'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#        'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#        'id': '1r4hJ1h58CWwUQe3MxPuau',
#        'name': 'Maluma',
#        'type': 'artist',
#        'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 184435,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'USSD11900034'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/31UjYv5vLsDkzchJOtUMtW'},
#      'href': 'https://api.spotify.com/v1/tracks/31UjYv5vLsDkzchJOtUMtW',
#      'id': '31UjYv5vLsDkzchJOtUMtW',
#      'is_local': False,
#      'name': 'HP',
#      'popularity': 93,
#      'preview_url': 'https://p.scdn.co/mp3-preview/623d8b9aad1987d810209f6c356679b1ebd2cd72?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:31UjYv5vLsDkzchJOtUMtW'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wkoKEfS6dXwThbyTnZWFU'},
#         'href': 'https://api.spotify.com/v1/artists/2wkoKEfS6dXwThbyTnZWFU',
#         'id': '2wkoKEfS6dXwThbyTnZWFU',
#         'name': 'Mau y Ricky',
#         'type': 'artist',
#         'uri': 'spotify:artist:2wkoKEfS6dXwThbyTnZWFU'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/0tmwSHipWxN12fsoLcFU3B'},
#         'href': 'https://api.spotify.com/v1/artists/0tmwSHipWxN12fsoLcFU3B',
#         'id': '0tmwSHipWxN12fsoLcFU3B',
#         'name': 'Manuel Turizo',
#         'type': 'artist',
#         'uri': 'spotify:artist:0tmwSHipWxN12fsoLcFU3B'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/28gNT5KBp7IjEOQoevXf9N'},
#         'href': 'https://api.spotify.com/v1/artists/28gNT5KBp7IjEOQoevXf9N',
#         'id': '28gNT5KBp7IjEOQoevXf9N',
#         'name': 'Camilo',
#         'type': 'artist',
#         'uri': 'spotify:artist:28gNT5KBp7IjEOQoevXf9N'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0vfE72mb2weKSONtBC6SPJ'},
#       'href': 'https://api.spotify.com/v1/albums/0vfE72mb2weKSONtBC6SPJ',
#       'id': '0vfE72mb2weKSONtBC6SPJ',
#       'images': [{'height': 640,
# ...
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/03KcW1ZhaSnj8pIk1LUNQs'},
#       'href': 'https://api.spotify.com/v1/albums/03KcW1ZhaSnj8pIk1LUNQs',
#       'id': '03KcW1ZhaSnj8pIk1LUNQs',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/77eb7c17cafe55033929e99114f40e4b81e2572b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/77eb7c17cafe5502e591e1515daa9d67250f9bf0',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/77eb7c17cafe55010107435b7f9b41d4904d1a4f',
#         'width': 64}],
#       'name': 'DUMMY BOY',
#       'release_date': '2018-11-27',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:03KcW1ZhaSnj8pIk1LUNQs'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gZfnEnfiaHzxARJ2LeXrf'},
#        'href': 'https://api.spotify.com/v1/artists/7gZfnEnfiaHzxARJ2LeXrf',
#        'id': '7gZfnEnfiaHzxARJ2LeXrf',
#        'name': '6ix9ine',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gZfnEnfiaHzxARJ2LeXrf'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#        'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#        'id': '2R21vXR83lH98kGeO99Y66',
#        'name': 'Anuel Aa',
#        'type': 'artist',
#        'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 217822,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'QMEU31816243'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4KkUjFkcQvGvWekl8RATDn'},
#      'href': 'https://api.spotify.com/v1/tracks/4KkUjFkcQvGvWekl8RATDn',
#      'id': '4KkUjFkcQvGvWekl8RATDn',
#      'is_local': False,
#      'name': 'BEBE (feat. Anuel Aa)',
#      'popularity': 86,
#      'preview_url': 'https://p.scdn.co/mp3-preview/bda115bbf4f1de770a9809a2d28dbde92b00b208?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:4KkUjFkcQvGvWekl8RATDn'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4'},
#         'href': 'https://api.spotify.com/v1/artists/540vIaP2JwjQb9dm3aArA4',
#         'id': '540vIaP2JwjQb9dm3aArA4',
#         'name': 'DJ Snake',
#         'type': 'artist',
#         'uri': 'spotify:artist:540vIaP2JwjQb9dm3aArA4'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#         'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#         'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#         'name': 'Selena Gomez',
#         'type': 'artist',
#         'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#         'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#         'id': '1i8SpTcr7yvPOmcqrbnVXY',
#         'name': 'Ozuna',
#         'type': 'artist',
#         'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0ZHyvPke0EcVt6rYA8Ins3'},
#       'href': 'https://api.spotify.com/v1/albums/0ZHyvPke0EcVt6rYA8Ins3',
#       'id': '0ZHyvPke0EcVt6rYA8Ins3',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/cca02c139eb4270d5e396086329c97c782c7b478',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/413d80d826a9122a718d2e94898bd2c8e26b32da',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/e2fcca62dcd299d8435f35d7c8f323dc7c18da9b',
#         'width': 64}],
#       'name': 'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#       'release_date': '2018-09-28',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:0ZHyvPke0EcVt6rYA8Ins3'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/540vIaP2JwjQb9dm3aArA4'},
#        'href': 'https://api.spotify.com/v1/artists/540vIaP2JwjQb9dm3aArA4',
#        'id': '540vIaP2JwjQb9dm3aArA4',
#        'name': 'DJ Snake',
#        'type': 'artist',
#        'uri': 'spotify:artist:540vIaP2JwjQb9dm3aArA4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#        'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#        'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#        'name': 'Selena Gomez',
#        'type': 'artist',
#        'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#        'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#        'id': '1i8SpTcr7yvPOmcqrbnVXY',
#        'name': 'Ozuna',
#        'type': 'artist',
#        'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#        'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#        'id': '4kYSro6naA4h99UJvo89HB',
#        'name': 'Cardi B',
#        'type': 'artist',
#        'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 212500,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUG11801723'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4w8niZpiMy6qz1mntFA5uM'},
#      'href': 'https://api.spotify.com/v1/tracks/4w8niZpiMy6qz1mntFA5uM',
#      'id': '4w8niZpiMy6qz1mntFA5uM',
#      'is_local': False,
#      'name': 'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#      'popularity': 94,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4w8niZpiMy6qz1mntFA5uM'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '1970-01-01T00:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C29ETLBPmYKYwtJUepbJz'},
#         'href': 'https://api.spotify.com/v1/artists/4C29ETLBPmYKYwtJUepbJz',
#         'id': '4C29ETLBPmYKYwtJUepbJz',
#         'name': 'Seven Kayne',
#         'type': 'artist',
#         'uri': 'spotify:artist:4C29ETLBPmYKYwtJUepbJz'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/4m6ubhNsdwF4psNf3R8kwR'},
#         'href': 'https://api.spotify.com/v1/artists/4m6ubhNsdwF4psNf3R8kwR',
#         'id': '4m6ubhNsdwF4psNf3R8kwR',
#         'name': 'Khea',
#         'type': 'artist',
#         'uri': 'spotify:artist:4m6ubhNsdwF4psNf3R8kwR'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fT2Me47PQ8T7954PKrcwR'},
#         'href': 'https://api.spotify.com/v1/artists/7fT2Me47PQ8T7954PKrcwR',
#         'id': '7fT2Me47PQ8T7954PKrcwR',
#         'name': 'Bhavi',
#         'type': 'artist',
#         'uri': 'spotify:artist:7fT2Me47PQ8T7954PKrcwR'}],
#       'available_markets': ['AD',
#        'AE',
#        'AR',
#        'AT',
#        'AU',
#        'BE',
#        'BG',
#        'BH',
#        'BO',
#        'BR',
#        'CA',
#        'CH',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DE',
#        'DK',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FR',
#        'GB',
#        'GR',
#        'GT',
#        'HK',
#        'HN',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KW',
#        'LB',
#        'LI',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MT',
#        'MX',
#        'MY',
#        'NI',
#        'NL',
#        'NO',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'SA',
#        'SE',
#        'SG',
#        'SK',
#        'SV',
#        'TH',
#        'TN',
#        'TR',
#        'TW',
#        'US',
#        'UY',
#        'VN',
#        'ZA'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0Wai6umy1E7IWqsKUASoyT'},
#       'href': 'https://api.spotify.com/v1/albums/0Wai6umy1E7IWqsKUASoyT',
#       'id': '0Wai6umy1E7IWqsKUASoyT',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/069b7412d709eb3abb37069e3f3159026457b002',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/033e3c812ed442bfe44f3b586b3b11f0b4e89565',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/55131c790c92364a1a43d5a254717f53666a9213',
#         'width': 64}],
#       'name': 'Buenos Aires',
#       'release_date': '2019-03-22',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:0Wai6umy1E7IWqsKUASoyT'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C29ETLBPmYKYwtJUepbJz'},
#        'href': 'https://api.spotify.com/v1/artists/4C29ETLBPmYKYwtJUepbJz',
#        'id': '4C29ETLBPmYKYwtJUepbJz',
#        'name': 'Seven Kayne',
#        'type': 'artist',
#        'uri': 'spotify:artist:4C29ETLBPmYKYwtJUepbJz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4m6ubhNsdwF4psNf3R8kwR'},
#        'href': 'https://api.spotify.com/v1/artists/4m6ubhNsdwF4psNf3R8kwR',
#        'id': '4m6ubhNsdwF4psNf3R8kwR',
#        'name': 'Khea',
#        'type': 'artist',
#        'uri': 'spotify:artist:4m6ubhNsdwF4psNf3R8kwR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fT2Me47PQ8T7954PKrcwR'},
#        'href': 'https://api.spotify.com/v1/artists/7fT2Me47PQ8T7954PKrcwR',
#        'id': '7fT2Me47PQ8T7954PKrcwR',
#        'name': 'Bhavi',
#        'type': 'artist',
#        'uri': 'spotify:artist:7fT2Me47PQ8T7954PKrcwR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'disc_number': 1,
#      'duration_ms': 210035,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'CA5KR1918206'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/42NACeANuRucHuCOFL5umq'},
#      'href': 'https://api.spotify.com/v1/tracks/42NACeANuRucHuCOFL5umq',
#      'id': '42NACeANuRucHuCOFL5umq',
#      'is_local': False,
#      'name': 'Buenos Aires (feat. Khea, Bhavi)',
#      'popularity': 68,
#      'preview_url': 'https://p.scdn.co/mp3-preview/78ac21840e04852a277e275ebf0f7989bfe24341?cid=4b454f446d1f479082eec9de1c27a4a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:42NACeANuRucHuCOFL5umq'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 50},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:37i9dQZEVXbMMy2roB9myp'}

# %%
    print("--------------------------\nLooping through Files\n--------------------------")

    # Loops through each playlist in playlist_json
    for i in range(number_of_tracks):
        time.sleep(0.02)
        
        try:
            # Store track json as variable for faster access
            playlist_tracks = playlist_json["tracks"]["items"][i]["track"]
            
            # Append artist name, artist ID, track name, track ID, release date, and popularity
            artist_name.append(playlist_tracks["album"]["artists"][0]["name"])
            artist_id.append(playlist_tracks["album"]["artists"][0]["id"])
            track_name.append(playlist_tracks["name"])
            
            # Store track ID as variable for faster access
            track_ids = playlist_tracks["id"]
            track_id.append(track_ids)
            
            #release_date.append(playlist_tracks["album"]["release_date"])
            #popularity.append(playlist_tracks["popularity"])
            
            # Accessing audio endpoint from spotify
            #audio_url = search_url_audio + track_ids

            #audio_json = requests.get(audio_url, headers = token_headers).json()
            
            # Append danceability and energy score
            #danceability.append(audio_json["danceability"])
            #energy.append(audio_json["energy"])
            
        except (KeyError, IndexError):
            danceability.append("NaN")
            energy.append("NaN")
            
            print(f"Could not find audio ID | {track_ids}")
    
    #Create DataFrame to store into excel
    artist_country_df = pd.DataFrame({"Artists Name" : artist_name,
                                      "Artist ID" : artist_id,
                                      "Track Name" : track_name,
                                      "Track ID" : track_id,
                                      #"Release Date" : release_date,
                                      #"Popularity" : popularity,
                                      #"Danceability" : danceability,
                                      #"Energy" : energy
                                     })
    
    # Country Name
    country = top50_playlist_df["Country"][counter]
    
#     # Export dataframe of each country into seperate excel files
    artist_country_df.to_csv(f"{path}/{country}_top_50.csv")
#     artist_country_df.to_sql(name=f'{country}', con=engine, if_exists='append', index=True)
    
    counter += 1
    
print("--------------------------\nDone Exporting to CSV Files\n--------------------------")
# Out:
# --------------------------
# Looping through Files
# --------------------------
# --------------------------
# Done Exporting to CSV Files
# --------------------------

# %%
artist_country_df
